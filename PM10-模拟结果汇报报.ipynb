# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # <font color='steelblue'><center> $PM_{10}$模拟数据评估 </center></font>

# %% [markdown]
#   <right>郝宇放 2016年 4月5日</right>

# %% [markdown]
# ## 1. 全年各站点浓度模拟 v.s 实际

# %% [markdown]
# ####  <font color='steelblue'>由全年模拟情况可以看出:</font>
# * 除人民会堂点位外，各受体点模拟浓度均小于实际浓度
# * 各点差距分别在-35.3, -24.4  26.1 , -38.1, -51.6, -57.2, -50.6 $\mu g/m^3$
# * 西北水源，西南高教以及职工医院点位的模拟值比实际明显偏小，但各月情况不同。需进一步分析

# %% [markdown]
# ## 2. 各月7站点模拟浓度v.s 观测浓度

# %% [markdown]
# 注: 绘图中各散点表示各受体点的浓度观测/模拟日均值

# %% [markdown]
# ####  <font color='steelblue'>各月浓度日均值：</font>
# * 一月与四月，部分实际观测值比模拟值偏差在两倍以上，部分数值吻合良好
# * 七月结果最为复杂，部分天数模拟值偏低，而部分天数模拟结果高于观测浓度两倍？
# * 十月份的模拟结果与实际吻合较好，除部分模拟值偏高外，大部分天数都与观测值偏差不大

# %% [markdown]
#  <font color='white'>1</font>
#   <font color='white'>1</font>

# %% [markdown]
# ####  <font color='steelblue'>各月浓度月均值</font>
# * 一月与四月，模拟均值是真实观测浓度的43.1%,50.8%
# * 七月与十月，模拟PM10浓度量级与真实观测值吻合良好，二者差值分别为15.3, 5.62微克/立方米

# %% [markdown]
# ## 3. 各月相关性的比较

# %% [markdown]
# 注: 1. 各月均选择4个受体点，对各点的观测日均值和模拟日均值的趋势进行绘制，并求得相关系数r
#    2. 蓝色实代表模拟值，红色虚线

# %% [markdown]
# ### 3.1$\ $  一月

# %% [markdown]
# ### 3.2$\ $  四月

# %% [markdown]
# ### 3.3 $\ $ 7月

# %% [markdown]
# ### 3.4$\ $  十月

# %% [markdown]
# #### <font color='steelblue'>各月相关性分析</font>
# 1. 整体上看，7月份模拟浓度与实际情况吻合较差
# 2. 一月份的模拟浓度趋势与实际$PM_{10}$变化趋势相近，但峰值明显偏低
# 3. 四月份各受体点与真实浓度有一定的相关性。从数值上看，各点情况不一:
#    部分点位模拟值明显小于实际浓度(如世纪公园)，部分点位模拟值有时会出现与真实情况不符的峰值(如职工医院)
#
# 4. 十月份模拟浓度与真实，其中世纪公园和职工医院两个受体点均很好地模拟出了$PM_{10}$的部分日均值峰值情况
