# %% [markdown]
# ## __IE Calibration__
#
# __28.05.2021__
#
#
# Today, we tested 5 different concentrations of NH4NO3 standards with both AMS and SMPS for calibrating the IE values.
#
# Ideally, we assumed the results from SMPS were reliable, and then transform the volume conc to mass conc with the density of NH4NO3 (1.725 ug/m3). Then, the fitted line of mass conc from AMS and SMPS were obtained, in which the slope will be used to correct the IE values for matching the results.
#
# For AMS,   $Nitrate\ (\mu g\ m^{-3}) = HRNO_{3}\cdot (M_{NO_3}+M_{NH_4})/M_{NO_3} = 1.299\cdot HRNO_{3}$
#
# For SMPS, $Nitrate\ (\mu g\ m^{-3}) = 1.725\ g\cdot cm^{-3}\cdot 10^{-9}\cdot Volume\ Conc\ (nm^{3}\cdot m^{-3}) $
#
# _Note: shape factor was not used this time_

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### __1. Experimental Results__

# %% [markdown]
# | Conc (ppm)   |   HROrg_AMS (ug/m3) |   NH4NO3_AMS (ug/m3) |   NH4NO3_SMPS (nm3/m3) |   NH4NO3_SMPS (ug/m3) |
# |:-------------|--------------------:|---------------------:|-----------------------:|----------------------:|
# | 20           |              61.778 |               80.232 |               1.45e+11 |               249.735 |
# | 10           |              26.991 |               35.053 |               7.77e+10 |               134.093 |
# | 5            |              12.918 |               16.777 |               4.68e+10 |                80.685 |
# | 2            |               6.017 |                7.814 |               2.89e+10 |                49.916 |
# | 1            |               3.623 |                4.706 |               2.06e+10 |                35.503 |
# | water blank  |               1.518 |                1.972 |               1.41e+10 |                24.388 |

# %% [markdown]
# ### 2. __Linear fitting__

# %%
print(f'Original IE = 5.3E-08')
# Out:
# Original IE = 5.3E-08

# %%
print(f'With water blank extration')
# Out:
# With water blank extration

# %% [markdown]
# <figure class="left">
#   <img class="top" src="https://i.stack.imgur.com/y5kai.png" width="600" height="400"/>
# </figure>
#
# <figure class="right">
#   <img class="average" src="https://i.stack.imgur.com/N6dD7.png" width="600" height="400"/>
# </figure>

# %%
print(f'Without water blank extration')
# Out:
# Without water blank extration

# %% [markdown]
# <figure class="left">
#   <img class="top" src="https://i.stack.imgur.com/fKPdv.png" width="600" height="400"/>
# </figure>
#
# <figure class="right">
#   <img class="average" src="https://i.stack.imgur.com/Ild5c.png" width="600" height="400"/>
# </figure>

# %% [markdown]
# ### 3. __Supplemental information__
#
# 3.1 AMS HRNO3 time series & raw data

# %% [markdown]
# <img src="https://i.stack.imgur.com/taM5n.jpg" width = '900'>

# %%
# df2 = pd.read_clipboard()

# %%
from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 align="left"><font size=2>{title}</font></h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)
pd.options.display.float_format = "{:,.2f}".format    

conc=["20 ppm", "10 ppm", "5 ppm",'2 ppm','1 ppm','water']
for i in range(0,6,1):
    globals()['ams_d' + str(i)] = df2[df2.Standard==conc[i]]
    
    globals()['ams_d' + str(i)] = globals()['ams_d' + str(i)].reset_index()
    globals()['ams_d' + str(i)] = globals()['ams_d' + str(i)][globals()['ams_d' + str(i)].columns[1:-1]]

# %%
display_side_by_side(ams_d0,ams_d1,ams_d2, titles=['20 ppm','10 ppm','5 ppm',])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2
td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4:21:36 PM</td>
#       <td>3.69</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4:21:47 PM</td>
#       <td>3.61</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4:21:57 PM</td>
#       <td>3.76</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>4:22:08 PM</td>
#       <td>3.78</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>4:22:19 PM</td>
#       <td>3.59</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4:22:30 PM</td>
#       <td>3.83</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4:22:41 PM</td>
#       <td>3.82</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>4:22:52 PM</td>
#       <td>3.68</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>4:23:03 PM</td>
#       <td>3.71</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>4:23:14 PM</td>
#       <td>3.57</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>4:23:25 PM</td>
#       <td>3.66</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>4:23:36 PM</td>
#       <td>3.58</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>4:23:47 PM</td>
#       <td>3.42</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>4:23:58 PM</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>4:24:09 PM</td>
#       <td>3.43</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>4:24:20 PM</td>
#       <td>3.40</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>4:24:31 PM</td>
#       <td>3.51</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>4:24:42 PM</td>
#       <td>3.45</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>water blank</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>HROrg (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4:27:15 PM</td>
#       <td>1.86</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4:27:26 PM</td>
#       <td>1.63</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4:27:37 PM</td>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4:27:48 PM</td>
#       <td>1.83</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4:27:59 PM</td>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4:28:10 PM</td>
#       <td>1.81</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>4:28:21 PM</td>
#       <td>1.76</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>4:28:32 PM</td>
#       <td>1.68</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4:28:43 PM</td>
#       <td>1.73</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4:28:54 PM</td>
#       <td>1.63</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>4:29:05 PM</td>
#       <td>1.68</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>4:29:15 PM</td>
#       <td>1.69</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>4:29:26 PM</td>
#       <td>1.70</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>4:29:37 PM</td>
#       <td>1.66</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>4:29:48 PM</td>
#       <td>1.66</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>4:29:59 PM</td>
#       <td>1.58</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>4:30:10 PM</td>
#       <td>1.51</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>4:30:21 PM</td>
#       <td>1.60</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>4:30:32 PM</td>
#       <td>1.53</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>4:30:43 PM</td>
#       <td>1.56</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>4:30:54 PM</td>
#       <td>1.58</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>4:31:05 PM</td>
#       <td>1.47</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>4:31:16 PM</td>
#       <td>1.49</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>4:31:27 PM</td>
#       <td>1.49</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>4:31:38 PM</td>
#       <td>1.50</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>4:31:49 PM</td>
#       <td>1.44</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>4:32:00 PM</td>
#       <td>1.46</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>4:32:11 PM</td>
#       <td>1.41</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>4:32:22 PM</td>
#       <td>1.34</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# 3.2 SMPS raw data

# %%
df3 = pd.read_clipboard()

# %%
conc=["20 ppm", "10 ppm", "5 ppm",'2 ppm','1 ppm','water blank']
for i in range(0,6,1):
    globals()['smps_d' + str(i)] = df3[df3.Standard==conc[i]]
    
    globals()['smps_d' + str(i)] = globals()['smps_d' + str(i)].reset_index()
    globals()['smps_d' + str(i)] = globals()['smps_d' + str(i)][globals()['smps_d' + str(i)].columns[1:-1]]

# %%
display_side_by_side(smps_d0,smps_d1,smps_d2, titles=['20 ppm','10 ppm','5 ppm',])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>20 ppm</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15:59:37</td>
#       <td>143,000,000,000.00</td>
#       <td>247.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:01:08</td>
#       <td>145,000,000,000.00</td>
#       <td>250.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:02:39</td>
#       <td>146,000,000,000.00</td>
#       <td>252.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>10 ppm</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16:04:10</td>
#       <td>79,200,000,000.00</td>
#       <td>137.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:05:41</td>
#       <td>78,600,000,000.00</td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:07:12</td>
#       <td>75,400,000,000.00</td>
#       <td>130.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>5 ppm</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16:08:43</td>
#       <td>48,200,000,000.00</td>
#       <td>83.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:10:14</td>
#       <td>46,900,000,000.00</td>
#       <td>80.80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:11:45</td>
#       <td>45,200,000,000.00</td>
#       <td>78.00</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
display_side_by_side(smps_d3,smps_d4,smps_d5, titles=['2 ppm','1 ppm','water blank',])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>2 ppm</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16:13:16</td>
#       <td>30,600,000,000.00</td>
#       <td>52.70</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:14:47</td>
#       <td>29,300,000,000.00</td>
#       <td>50.50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:16:18</td>
#       <td>29,400,000,000.00</td>
#       <td>50.70</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16:17:49</td>
#       <td>28,200,000,000.00</td>
#       <td>48.70</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16:19:20</td>
#       <td>27,200,000,000.00</td>
#       <td>46.90</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>1 ppm</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16:22:22</td>
#       <td>21,500,000,000.00</td>
#       <td>37.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:23:53</td>
#       <td>19,800,000,000.00</td>
#       <td>34.20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:25:24</td>
#       <td>20,400,000,000.00</td>
#       <td>35.30</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 align="left"><font size=2>water blank</font></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>SMPS volume conc (nm3/m3)</th>
#       <th>SMPS mass conc (ug/m3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16:28:26</td>
#       <td>15,700,000,000.00</td>
#       <td>27.10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16:29:57</td>
#       <td>14,700,000,000.00</td>
#       <td>25.30</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16:31:28</td>
#       <td>14,300,000,000.00</td>
#       <td>24.60</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16:32:59</td>
#       <td>13,200,000,000.00</td>
#       <td>22.80</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16:34:30</td>
#       <td>12,800,000,000.00</td>
#       <td>22.10</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# 3.3 Pika relevant figures

# %% [markdown]
# <figure class="left">
#   <h2 align="left"><font size=2>Peak width fit graph</font></h2>
#   <img class="top" src="https://i.stack.imgur.com/B5w8a.jpg" width="500" height="300"/>
# </figure>
# <figure class="right">
#   <h2 align="left"><font size=2>Peak shape</font></h2>
#   <img class="average" src="https://i.stack.imgur.com/aqZgx.jpg" width="500" height="300"/>
# </figure>

# %% [markdown]
# <figure class="left">
#   <h2 align="left"><font size=2>m/z 30 peak fitting</font></h2>
#   <img class="top" src="https://i.stack.imgur.com/yi6QP.jpg" width="500" height="300"/>
# </figure>
# <figure class="right">
#   <h2 align="left"><font size=2>m/z 46 peak fitting</font></h2>
#   <img class="average" src="https://i.stack.imgur.com/BcjmS.jpg" width="500" height="300"/>
# </figure>
