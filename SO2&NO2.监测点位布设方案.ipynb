# %% [markdown]
# # <font color='steelblue'><center> $SO_2$ 以及 $NO_2$监测点位布设方案 </center></font>

# %% [markdown]
# <right>郝宇放 2016年 1月21日</right>

# %% [markdown]
# ## 1. 模拟数据质量评估

# %% [markdown]
# ### 1.1 各季节特征月份 $SO_2$ 以及 $NO_2$ 浓度日均浓度值模拟 v.s 实际

# %% [markdown]
# #### 从上图可以看出
# * $SO_2$ 和 $NO_2$ 整体情况上看, 模拟值多小于实测浓度
# * $SO_2$ 在4、7、10月的模拟效果较好，而1月份的模拟值明显偏低
# * $NO_2$ 在1、4月的模拟效果较好，而7、10两月部分日均值模拟值明显偏低(结合图2)

# %% [markdown]
# ### 1.2 各特征月份浓度比较

# %% [markdown]
# ## 2. 潜在监测点位的识别与排序

# %% [markdown]
# 应用calpuff模型模拟了2014年各季节代表性月份1、4、7和10月份石家庄市$SO_2$、$NO_2$以及$PM_{10}$的逐时浓度值。基于下述方程计算年日均值作为对应的浓度场FOM:
#
#  <center>$FOM_{(x,y)} =  \frac{\sum_{i=1}^{4}\sum_{j=1}^{30/31}\sum_{t=1}^{24}C(x,y)_{i,j,t}}{\sum_{i=1}^{4}\sum_{j=1}^{30/31}\sum_{t=1}^{24}}$  </center>
#
# * i、j 和 t 分别表示月、天和时刻
# * $C(x,y)_{i,j,t}$表示第 i 月第 j 天 t 时刻位于(x, y)处大气污染物的浓度值

# %% [markdown]
# #### <font color='blue'><center>潜在监测点识别的原则，是搜寻 FOM 场中最高值。</center></font>

# %% [markdown]
# ### 2.1  $SO_2$ FOM 浓度场的分布特征

# %% [markdown]
# ##### <center>$SO_2$备选点位排序和具体分布</center>

# %% [markdown]
# | 编号 |x 轴(km) | Y 轴 (km) |
# | ------------ | ------------- | ------------ |
# | 1 | 5  | 23 |
# | 2 | 21  | 0 |
# | 3 | 11  | 17 |
# | 4 | 21  | 1 |
# | 5 | 10  | 17 |
# | ... | ...  | ... |

# %% [markdown]
# ### 2.2  $NO_2$ FOM 浓度场的分布特征

# %% [markdown]
# ##### <center>$NO_2$备选点位排序和具体分布</center>

# %% [markdown]
# | 编号 |x 轴(km) | Y 轴 (km) |
# | ------------ | ------------- | ------------ |
# | 1 | 4  | 20|
# | 2 | 2  | 20 |
# | 3 | 1  | 20 |
# | 4 | 5  | 20 |
# | 5 | 6  | 19 |
# | ... | ...  | ... |

# %% [markdown]
# * 上述图中的$SO_2$与$NO_2$的浓度峰,将作为一个潜在的环境空气质量监测点位，
# * 根据 FOM 值大小将选择的潜在监测点位排序
# * $SO_2$高浓度分布区域主要处在城区西北部及东南部位置
# * $NO_2$高浓度分布区域主要处在城区西北部
#
# 接下来，会根据识别出的潜在监测点位，通过统计确定需要监测站点的最少数量，以建立最优监测网络。

# %% [markdown]
# ### 3. 最少数量监测点位的确定

# %% [markdown]
# 1. 计算每一个排序监测站点的影响范围，完成优化网络结构或需要的最小监测站点数的确定。
# 2. 用规定置信水平下的空间相关系数及其界限值，依次确定每一个潜在监测站点的影响范围分布。
# 3. 以模型模拟获得浓度场作为基础数据，评估识别的每一个监测位
#
# 多次测试后 选择截断相关系数 $r_c = 0.75$

# %% [markdown]
# ### <font color='green'>筛选标准</font>
# > 如果在消除已由较高排序站点覆盖范围的重叠区域后，其单独区域的覆盖范围小于
# > 最高排序站点覆盖范围的10%，则从名单中删除此站点

# %% [markdown]
# #### $SO_2$布点区域

# %% [markdown]
# ##### * 注明： 部分点位的覆盖区域被覆盖，无法看清。原因在于：
# 其位点排序位次较高(相对浓度高值区)，在筛选点位过程中，删去排序在其前点位的重叠覆盖面积后，仍有一定的独立代表面积，故予以保留

# %% [markdown]
# #### <font color='blue'><center>石家庄市大气 $SO_2$ 潜在监测点位识别结果</center></font>
#
# <center>点位总数为10, 累积覆盖面积为 336 $km^2$</center></font>
#
# | 编号 |x 轴(km) | Y 轴 (km) | 单个站点覆盖面积 ($km^2$) |累积覆盖面积 ($km^2$) | 累积覆盖面积比例  |
# | ------------ | ------------- | ------------ |------------ | ------------- | ------------ |
# | 1 | 19 | 15|20 | 20  | 1.77%|
# | 2 | 10  | 5 | 34 | 57  | 4.79%|
# | 3 | 16  | 5 | 90 |  134 | 11.88% |
# | 4 | 16  | 6 | 116 | 158  | 14.01% |
# | 5 | 16  | 8 | 92 | 178  | 15.78% |
# | 6 | 6  | 10|46 | 220  | 19.50%|
# | 7 | 12  | 10 | 106 | 262  | 22.34% |
# | 8 | 24  | 13 | 20 | 294  | 24.11% |
# | 9 | 26  | 13 | 20 | 314  | 25.89% |
# | 10 | 10  | 19 | 74 | 336  | 27.84% |

# %% [markdown]
# #### $NO_2$布点区域

# %% [markdown]
# <font color='blue'><center>石家庄市大气 $NO_2$ 潜在监测点位识别结果</center></font>
#
# <center>点位总数为9, 累积覆盖面积为 608 $km^2$</center></font>
#
# | 编号 |x 轴(km) | Y 轴 (km) | 单个站点覆盖面积 ($km^2$) |累积覆盖面积 ($km^2$) | 累积覆盖面积比例  |
# | ------------ | ------------- | ------------ |------------ | ------------- | ------------ |
# | 1 | 15  | 9 |46 | 44  | 3.90% |
# | 2 | 16  | 9 | 118 | 110  | 9.75% |
# | 3 | 6  | 10 | 46 | 156 | 13.83% |
# | 4 | 7  | 11 | 74 | 192  | 17.02% |
# | 5 | 11  | 11 | 122 | 243  | 21.10% |
# | 6 | 20  | 11 |90 | 286  | 25.35%|
# | 7 | 16  | 5 | 334 | 358  | 31.73% |
# | 8 | 23  | 19 | 226 | 590  | 50.53% |
# | 9 | 22  | 12 | 92 | 608  | 53.72% |

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
